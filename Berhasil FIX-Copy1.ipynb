# %%
import numpy as np
import math

def read_tsp_file(file_path):
    city_coordinates = {}
    with open(file_path, 'r') as file:
        # Temukan awal dari NODE_COORD_SECTION
        for line in file:
            if line.strip() == "NODE_COORD_SECTION":
                break
        
        # Baca data koordinat kota
        for line in file:
            if line.strip() == "EOF":
                break
            # Split line and convert values to integers
            values = list(map(int, line.split()))
            
            if len(values) == 2:
                # If there are two values, assume (x, y) and use the line number as city_id
                city_id = len(city_coordinates) + 1
                x, y = values
            elif len(values) == 3:
                # If there are three values, assume (city_id, x, y)
                city_id, x, y = values
            else:
                # Handle other cases as needed
                continue
            
            city_coordinates[city_id] = (x, y)
    
    return city_coordinates

file_path = 'D:/att48.tsp'
city_coordinates = read_tsp_file(file_path)

# Function to calculate Euclidean distance
def euclidean_distance(city1, city2):
    return math.sqrt((city1[0] - city2[0])**2 + (city1[1] - city2[1])**2)

# Generate initial population
def generate_initial_population(city_coordinates, population_size):
    city_ids = list(city_coordinates.keys())
    population = [np.random.permutation(city_ids).tolist() for _ in range(population_size)]
    return population

# Calculate total distance of a path
def calculate_total_distance(path, city_coordinates):
    total_distance = 0
    for i in range(len(path)):
        from_city = city_coordinates[path[i]]
        to_city = city_coordinates[path[(i + 1) % len(path)]]  # Loop back to start
        total_distance += euclidean_distance(from_city, to_city)
    return total_distance

# Fitness evaluation
def evaluate_fitness(population, city_coordinates):
    fitness_scores = []
    for individual in population:
        distance = calculate_total_distance(individual, city_coordinates)
        fitness_score = 1 / distance  # Higher fitness for shorter path
        fitness_scores.append(fitness_score)
    return np.array(fitness_scores)

# Selection - Roulette Wheel Selection
def select_parents(population, fitness_scores, num_parents):
    parents = []
    for _ in range(num_parents):
        parent_idx = np.random.choice(np.arange(len(population)), p=fitness_scores/fitness_scores.sum())
        parents.append(population[parent_idx])
    return parents

# # Crossover - Ordered Crossover
# def ordered_crossover(parent1, parent2):
#     size = len(parent1)
#     start, end = sorted(np.random.sample(2) * size)
#     child = [None]*size
#     child[int(start):int(end)] = parent1[int(start):int(end)]
#     fill_values = [item for item in parent2 if item not in child]
#     child = [item if item is not None else fill_values.pop(0) for item in child]
#     return child
def two_point_crossover(parent1, parent2):
    size = len(parent1)
    # Hasilkan dua titik berbeda untuk saling bersilangan
    crossover_points = sorted(np.random.choice(range(1, size), 2, replace=False))
    start, end = crossover_points
    
    # Initialize the child with None
    """
    menginisialisasi daftar bernama child dengan panjang sama dengan size, dimana setiap elemen dalam daftar awalnya disetel ke None.
    Menginisialisasi [None] dapat membantu memeriksa error. 
    Setelah operasi crossover selesai, jika ada nilai None yang tersisa, hal ini menunjukkan bahwa algoritma 
    tidak mengisi array child dengan benar, yang dapat membantu dalam men-debug proses crossover.
    """
    child = [None] * size
    
    # Salin segmen dari parent1 ke anak
    child[start:end] = parent1[start:end]
    # Isi sisa rute dari induk2, pastikan tidak ada duplikat
    current_position = end
    for city in parent2:
        if city not in child:
            if current_position >= size:
                current_position = 0
            child[current_position] = city
            current_position += 1
    
    return child


# Mutation - Swap Mutation
def swap_mutation(individual, mutation_rate):
    if np.random.rand() < mutation_rate:
        idx1, idx2 = np.random.choice(len(individual), 2, replace=False)
        individual[idx1], individual[idx2] = individual[idx2], individual[idx1]
    return individual

# Jalankan algoritma genetika untuk TSP
def genetic_algorithm_tsp_with_elitism(city_coordinates, population_size=100, num_generations=500, mutation_rate=0.01, elitism_size=2):
    population = generate_initial_population(city_coordinates, population_size)
    for generation in range(num_generations):
        fitness_scores = evaluate_fitness(population, city_coordinates)
        total_fitness = np.sum(fitness_scores)
        best_distance = 1 / np.max(fitness_scores)
        
        # Elitisme: Cadangan individu terbaik dari populasi saat ini
        elite_indices = np.argsort(-fitness_scores)[:elitism_size]
        elites = [population[i] for i in elite_indices]
        
        # Hasilkan populasi berikutnya, tidak termasuk elit untuk saat ini
        next_population = []
        parents = select_parents(population, fitness_scores, population_size - elitism_size)
        for i in range(0, len(parents), 2):
            if i+1 < len(parents):  # Ensure there's a pair for crossover
                for child in [ordered_crossover(parents[i], parents[i+1]), ordered_crossover(parents[i+1], parents[i])]:
                    child = swap_mutation(child, mutation_rate)
                    next_population.append(child)
        
        # Tambahkan elit ke populasi berikutnya setelah mutasi
        next_population.extend(elites)
        
        population = next_population
        
        # Perbarui skor kebugaran berdasarkan populasi baru termasuk elit
        fitness_scores = evaluate_fitness(population, city_coordinates)
        best_distance = 1 / np.max(fitness_scores)  # Hitung ulang jarak terbaik dengan menyertakan elit
        
        # Display generation info
        print(f"Generasi {generation + 1}\nBest Distance = {best_distance}\nTotal Fitness = {total_fitness}\n")

    # Identifikasi solusi terbaik dalam populasi akhir
    best_idx = np.argmax(fitness_scores)
    best_solution = population[best_idx]
    return best_solution, best_distance

# Jalankan Algoritma Genetika dengan elitisme dan tampilkan hasilnya
best_path, best_distance = genetic_algorithm_tsp_with_elitism(city_coordinates)
print(f"\nBest Path:{best_path}\nBest Distance: {best_distance}")
# Out:
# Generasi 1
# Best Distance = 128998.17367022487
# Total Fitness = 0.0006351994035939977
#
# Generasi 2
# Best Distance = 128998.17367022487
# Total Fitness = 0.0006444708899463422
#
# Generasi 3
# Best Distance = 128998.17367022487
# Total Fitness = 0.0006487037740072894
#
# Generasi 4
# Best Distance = 125885.91881119314
# Total Fitness = 0.0006503304525806564
#
# Generasi 5
# Best Distance = 125885.91881119314
# Total Fitness = 0.0006567608781710531
#
# Generasi 6
# Best Distance = 125885.91881119314
# Total Fitness = 0.0006628611263908592
#
# Generasi 7
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006548592877155638
#
# Generasi 8
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006564817472789036
#
# Generasi 9
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006538510398549595
#
# Generasi 10
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006551091545230451
#
# Generasi 11
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006549977133654062
#
# Generasi 12
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006503254932192951
#
# Generasi 13
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006486005948070753
#
# Generasi 14
# Best Distance = 125801.36679706605
# Total Fitness = 0.0006510144909188367
#
# Generasi 15
# Best Distance = 119085.74352750978
# Total Fitness = 0.0006539898737754009
#
# Generasi 16
# Best Distance = 119085.74352750978
# Total Fitness = 0.0006709742810686516
#
# Generasi 17
# Best Distance = 119085.74352750978
# Total Fitness = 0.0006663827930563751
#
# Generasi 18
# Best Distance = 119085.74352750978
# Total Fitness = 0.00066180757321463
#
# Generasi 19
# Best Distance = 115703.24074301092
# Total Fitness = 0.0006700865155683198
#
# Generasi 20
# Best Distance = 115703.24074301092
# Total Fitness = 0.0006671998900968
#
# Generasi 21
# Best Distance = 115703.24074301092
# Total Fitness = 0.0006623692107870383
#
# Generasi 22
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006573936941766181
#
# Generasi 23
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006595694713601665
#
# Generasi 24
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006713021717864668
#
# Generasi 25
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006751842443740755
#
# Generasi 26
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006717637488925851
#
# Generasi 27
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006842093254811896
#
# Generasi 28
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006863277745218575
#
# Generasi 29
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006863540777915792
#
# Generasi 30
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006808242551581698
#
# Generasi 31
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006709805657009114
#
# Generasi 32
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006738918222474593
#
# Generasi 33
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006715547528688815
#
# Generasi 34
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006759979451130951
#
# Generasi 35
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006816216946086133
#
# Generasi 36
# Best Distance = 114235.11363185031
# Total Fitness = 0.0006921037748088045
#
# Generasi 37
# Best Distance = 110388.45475487597
# Total Fitness = 0.0007057937766190721
#
# Generasi 38
# Best Distance = 110388.45475487597
# Total Fitness = 0.0007035259057315409
#
# Generasi 39
# Best Distance = 109340.56576233917
# Total Fitness = 0.0006880687010592684
#
# Generasi 40
# Best Distance = 109340.56576233917
# Total Fitness = 0.0006955929861333473
#
# Generasi 41
# Best Distance = 108651.6449970234
# Total Fitness = 0.000702692541741291
#
# Generasi 42
# Best Distance = 108651.6449970234
# Total Fitness = 0.0007174438384195042
#
# Generasi 43
# Best Distance = 103271.57908599114
# Total Fitness = 0.0007133722229943397
#
# Generasi 44
# Best Distance = 103271.57908599114
# Total Fitness = 0.000703600222356411
#
# Generasi 45
# Best Distance = 103271.57908599114
# Total Fitness = 0.0007048374191462413
#
# Generasi 46
# Best Distance = 103271.57908599114
# Total Fitness = 0.0007150271286686571
#
# Generasi 47
# Best Distance = 103271.57908599114
# Total Fitness = 0.0007037130600704986
#
# Generasi 48
# Best Distance = 103271.57908599114
# Total Fitness = 0.0007092614668338171
#
# Generasi 49
# Best Distance = 103271.57908599114
# Total Fitness = 0.000712332649134907
#
# Generasi 50
# Best Distance = 103250.3444491119
# Total Fitness = 0.0006967581706299824
#
# Generasi 51
# Best Distance = 103250.3444491119
# Total Fitness = 0.0006995609022965147
#
# Generasi 52
# Best Distance = 103250.3444491119
# Total Fitness = 0.0007057660407507196
#
# Generasi 53
# Best Distance = 103250.3444491119
# Total Fitness = 0.0007175887165308412
#
# Generasi 54
# Best Distance = 103250.3444491119
# Total Fitness = 0.0007111547468785135
#
# Generasi 55
# Best Distance = 103250.3444491119
# Total Fitness = 0.000701045733963991
#
# Generasi 56
# Best Distance = 101978.44993589567
# Total Fitness = 0.0007028837924896723
#
# Generasi 57
# Best Distance = 101978.44993589567
# Total Fitness = 0.0007077059096998402
#
# Generasi 58
# Best Distance = 101978.44993589567
# Total Fitness = 0.0007131501041157136
#
# Generasi 59
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007190141503879595
#
# Generasi 60
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007337169743592072
#
# Generasi 61
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007377561646214469
#
# Generasi 62
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007393943156179832
#
# Generasi 63
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007581249376140871
#
# Generasi 64
# Best Distance = 101217.68336195764
# Total Fitness = 0.000768873206493175
#
# Generasi 65
# Best Distance = 101217.68336195764
# Total Fitness = 0.0007710170032435536
#
# Generasi 66
# Best Distance = 99121.99767055617
# Total Fitness = 0.0007702599998647325
#
# Generasi 67
# Best Distance = 99121.99767055617
# Total Fitness = 0.0007689869048774595
#
# Generasi 68
# Best Distance = 99121.99767055617
# Total Fitness = 0.0007708519507675138
#
# Generasi 69
# Best Distance = 99121.99767055617
# Total Fitness = 0.0007663567699837899
#
# Generasi 70
# Best Distance = 99121.99767055617
# Total Fitness = 0.0007562656027580961
#
# Generasi 71
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007558854031532695
#
# Generasi 72
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007753952527636712
#
# Generasi 73
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007844947283700307
#
# Generasi 74
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007712747434916423
#
# Generasi 75
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007776342683378655
#
# Generasi 76
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007639894586076513
#
# Generasi 77
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007572440683703701
#
# Generasi 78
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007514399762951487
#
# Generasi 79
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007465739194827918
#
# Generasi 80
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007557718583217525
#
# Generasi 81
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007502241859320298
#
# Generasi 82
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007378776286257503
#
# Generasi 83
# Best Distance = 98471.93275417009
# Total Fitness = 0.0007368673525000876
#
# Generasi 84
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007262751258278433
#
# Generasi 85
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007305239482562601
#
# Generasi 86
# Best Distance = 97816.71755975543
# Total Fitness = 0.000727404869352582
#
# Generasi 87
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007311799169849423
#
# Generasi 88
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007314087985099668
#
# Generasi 89
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007163977020889701
#
# Generasi 90
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007036085960520317
#
# Generasi 91
# Best Distance = 97816.71755975543
# Total Fitness = 0.0006963715256751128
#
# Generasi 92
# Best Distance = 97816.71755975543
# Total Fitness = 0.000693572131285814
#
# Generasi 93
# Best Distance = 97816.71755975543
# Total Fitness = 0.0006998002268265401
#
# Generasi 94
# Best Distance = 97816.71755975543
# Total Fitness = 0.0007094813942318618
#
# Generasi 95
# Best Distance = 97761.42997854347
# Total Fitness = 0.0007322281664104605
#
# Generasi 96
# Best Distance = 97761.42997854347
# Total Fitness = 0.0007577237179175343
#
# Generasi 97
# Best Distance = 96710.09531269931
# Total Fitness = 0.000762245474397761
#
# Generasi 98
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007712018036343052
#
# Generasi 99
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007534274408684524
#
# Generasi 100
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007585425363633934
#
# Generasi 101
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007518005850201063
#
# Generasi 102
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007563115489075178
#
# Generasi 103
# Best Distance = 96710.09531269931
# Total Fitness = 0.000750303109298316
#
# Generasi 104
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007381160554015118
#
# Generasi 105
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007381622188645752
# Generasi 106
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007282099269288009
#
# Generasi 107
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007370048044303167
#
# Generasi 108
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007328184149193029
#
# Generasi 109
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007502046302480612
#
# Generasi 110
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007365176052220494
#
# Generasi 111
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007400243914458996
#
# Generasi 112
# Best Distance = 96710.09531269931
# Total Fitness = 0.000743250121650488
#
# Generasi 113
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007358596789373533
#
# Generasi 114
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007394547296145312
#
# Generasi 115
# Best Distance = 96710.09531269931
# Total Fitness = 0.0007303605458025959
#
# Generasi 116
# Best Distance = 94075.89645224444
# Total Fitness = 0.0007188336608965483
#
# Generasi 117
# Best Distance = 94075.89645224444
# Total Fitness = 0.0007086888301148039
#
# Generasi 118
# Best Distance = 94075.89645224444
# Total Fitness = 0.0007024500522453919
#
# Generasi 119
# Best Distance = 89915.84043406574
# Total Fitness = 0.0007270933128968518
#
# Generasi 120
# Best Distance = 89915.84043406574
# Total Fitness = 0.0007455452774917578
#
# Generasi 121
# Best Distance = 89891.76563284933
# Total Fitness = 0.000747440228618234
#
# Generasi 122
# Best Distance = 89891.76563284933
# Total Fitness = 0.0007648120341338183
#
# Generasi 123
# Best Distance = 89891.76563284933
# Total Fitness = 0.0007821518664503514
#
# Generasi 124
# Best Distance = 89891.76563284933
# Total Fitness = 0.000758312471999531
#
# Generasi 125
# Best Distance = 89891.76563284933
# Total Fitness = 0.0007704328569466673
#
# Generasi 126
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007592297183210292
#
# Generasi 127
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007783157546075976
#
# Generasi 128
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007777612168715141
#
# Generasi 129
# Best Distance = 88716.94062567722
# Total Fitness = 0.000780014525450783
#
# Generasi 130
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007626475391405447
#
# Generasi 131
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007617144747075806
#
# Generasi 132
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007578474944380612
#
# Generasi 133
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007652511604996304
#
# Generasi 134
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007775386964815755
#
# Generasi 135
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007861610181035113
#
# Generasi 136
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007908807935478196
#
# Generasi 137
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007850763008326074
#
# Generasi 138
# Best Distance = 88716.94062567722
# Total Fitness = 0.0007881261959140223
#
# Generasi 139
# Best Distance = 87427.72866931539
# Total Fitness = 0.0007958719579201926
#
# Generasi 140
# Best Distance = 87427.72866931539
# Total Fitness = 0.0007980569461818226
#
# Generasi 141
# Best Distance = 87427.72866931539
# Total Fitness = 0.0007912695346111758
#
# Generasi 142
# Best Distance = 87427.72866931539
# Total Fitness = 0.0008073964412046552
#
# Generasi 143
# Best Distance = 87427.72866931539
# Total Fitness = 0.0008140361377808868
#
# Generasi 144
# Best Distance = 87427.72866931539
# Total Fitness = 0.0008030626875756819
#
# Generasi 145
# Best Distance = 87427.72866931539
# Total Fitness = 0.0008341643933175567
#
# Generasi 146
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008395685729686159
#
# Generasi 147
# Best Distance = 86322.7952977035
# Total Fitness = 0.000836633061509365
#
# Generasi 148
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008518602998997633
#
# Generasi 149
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008369735591451453
#
# Generasi 150
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008215708118371523
#
# Generasi 151
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008141942041127265
#
# Generasi 152
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008301501787681251
#
# Generasi 153
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008244040448092498
#
# Generasi 154
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008244503500466138
#
# Generasi 155
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008421146252003989
#
# Generasi 156
# Best Distance = 86322.7952977035
# Total Fitness = 0.000823055695670711
#
# Generasi 157
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008239571177075964
#
# Generasi 158
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008179370964208817
#
# Generasi 159
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008231503361834444
#
# Generasi 160
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008141914661987108
#
# Generasi 161
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007981343986831743
#
# Generasi 162
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007903957790753808
#
# Generasi 163
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007879674416306026
#
# Generasi 164
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007788401125433671
#
# Generasi 165
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007513221472168658
#
# Generasi 166
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007653833194281994
#
# Generasi 167
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007637383247407157
#
# Generasi 168
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007833231745386452
#
# Generasi 169
# Best Distance = 86322.7952977035
# Total Fitness = 0.000783309084989599
#
# Generasi 170
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007823469365723898
#
# Generasi 171
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008038629109605437
#
# Generasi 172
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007909663618536522
#
# Generasi 173
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007962359767686195
#
# Generasi 174
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008116764194346734
#
# Generasi 175
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008062651549272112
#
# Generasi 176
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008102919916968878
#
# Generasi 177
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007968506350658979
#
# Generasi 178
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008055627224949368
#
# Generasi 179
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007843080373476709
#
# Generasi 180
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007857128383821202
#
# Generasi 181
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007762220680892332
#
# Generasi 182
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007661518242017665
#
# Generasi 183
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007789064720032553
#
# Generasi 184
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007721365229761511
#
# Generasi 185
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007627362216845476
#
# Generasi 186
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007631928371296444
#
# Generasi 187
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007715642893333891
#
# Generasi 188
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007781321013843422
#
# Generasi 189
# Best Distance = 86322.7952977035
# Total Fitness = 0.000770867460939264
#
# Generasi 190
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007518694503478044
#
# Generasi 191
# Best Distance = 86322.7952977035
# Total Fitness = 0.000753141035392334
#
# Generasi 192
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007427226281801849
#
# Generasi 193
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007567134639431827
#
# Generasi 194
# Best Distance = 86322.7952977035
# Total Fitness = 0.000764195189923953
#
# Generasi 195
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007741626724749303
#
# Generasi 196
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007530782331732127
#
# Generasi 197
# Best Distance = 86322.7952977035
# Total Fitness = 0.000737216000157331
#
# Generasi 198
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007502139470558529
#
# Generasi 199
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007248916366737435
#
# Generasi 200
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007298323223512444
#
# Generasi 201
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007465804067468895
#
# Generasi 202
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007542381172010967
#
# Generasi 203
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007621011377027542
#
# Generasi 204
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007809222974033346
#
# Generasi 205
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007964386228898633
#
# Generasi 206
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007784583474393693
#
# Generasi 207
# Best Distance = 86322.7952977035
# Total Fitness = 0.0007997133614290788
#
# Generasi 208
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008129910034346314
#
# Generasi 209
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008121956095760849
#
# Generasi 210
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008451038015295746
#
# Generasi 211
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008479879188902925
#
# Generasi 212
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008560218826052324
#
# Generasi 213
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008363041884558707
#
# Generasi 214
# Best Distance = 86322.7952977035
# Total Fitness = 0.0008196227769669647
#
# Generasi 215
# Best Distance = 86194.10590819582
# Total Fitness = 0.0008219337844072907
#
# Generasi 216
# Best Distance = 86194.10590819582
# Total Fitness = 0.0008346979399387572
#
# Generasi 217
# Best Distance = 86194.10590819582
# Total Fitness = 0.0008224959376663156
#
# Generasi 218
# Best Distance = 86194.10590819582
# Total Fitness = 0.0008283311393809871
#
# Generasi 219
# Best Distance = 86194.10590819582
# Total Fitness = 0.000802644589536781
#
# Generasi 220
# Best Distance = 86194.10590819582
# Total Fitness = 0.0008172353075970119
#
# Generasi 221
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008493557293252562
#
# Generasi 222
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008586290127669035
# Generasi 223
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008427900199488319
#
# Generasi 224
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008432930015358715
#
# Generasi 225
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008453984104273126
#
# Generasi 226
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008550812069472848
#
# Generasi 227
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008649594344243488
#
# Generasi 228
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008775580306870758
#
# Generasi 229
# Best Distance = 85905.55727871039
# Total Fitness = 0.000890226247819402
#
# Generasi 230
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008664431298079011
#
# Generasi 231
# Best Distance = 85905.55727871039
# Total Fitness = 0.0008472687180530234
#
# Generasi 232
# Best Distance = 85785.09287518167
# Total Fitness = 0.0008183374872276632
#
# Generasi 233
# Best Distance = 85785.09287518167
# Total Fitness = 0.0008244893763372044
#
# Generasi 234
# Best Distance = 85785.09287518167
# Total Fitness = 0.0008119766084297256
#
# Generasi 235
# Best Distance = 85785.09287518167
# Total Fitness = 0.0007896451794253893
#
# Generasi 236
# Best Distance = 85785.09287518167
# Total Fitness = 0.0007770342645643509
#
# Generasi 237
# Best Distance = 85785.09287518167
# Total Fitness = 0.0007729915519941074
#
# Generasi 238
# Best Distance = 85785.09287518167
# Total Fitness = 0.00077000216035754
#
# Generasi 239
# Best Distance = 85785.09287518167
# Total Fitness = 0.0007767243321823281
#
# Generasi 240
# Best Distance = 81738.45858299825
# Total Fitness = 0.0007763711212506627
#
# Generasi 241
# Best Distance = 81738.45858299825
# Total Fitness = 0.0007728852323229919
#
# Generasi 242
# Best Distance = 81738.45858299825
# Total Fitness = 0.0007957421285977172
#
# Generasi 243
# Best Distance = 81738.45858299825
# Total Fitness = 0.0007940297290253704
#
# Generasi 244
# Best Distance = 81738.45858299825
# Total Fitness = 0.0007936600677663068
#
# Generasi 245
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008174160170790763
#
# Generasi 246
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008273738282469298
#
# Generasi 247
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008384628163445532
#
# Generasi 248
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008332970665369181
#
# Generasi 249
# Best Distance = 80433.80370601699
# Total Fitness = 0.0007988093652029116
#
# Generasi 250
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008096181344815709
#
# Generasi 251
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008263419897614399
#
# Generasi 252
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008427580912972036
#
# Generasi 253
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008286303567930631
#
# Generasi 254
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008244436416365748
#
# Generasi 255
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008014842713963762
#
# Generasi 256
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008051287570052245
#
# Generasi 257
# Best Distance = 80433.80370601699
# Total Fitness = 0.0007886708397737025
#
# Generasi 258
# Best Distance = 80433.80370601699
# Total Fitness = 0.0007663480407640851
#
# Generasi 259
# Best Distance = 80433.80370601699
# Total Fitness = 0.0007871298397688756
#
# Generasi 260
# Best Distance = 80433.80370601699
# Total Fitness = 0.0007925373012035515
#
# Generasi 261
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008031111041409548
#
# Generasi 262
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008018384888179446
#
# Generasi 263
# Best Distance = 80433.80370601699
# Total Fitness = 0.0008109846559002259
#
# Generasi 264
# Best Distance = 80344.35559499598
# Total Fitness = 0.000813183753045791
#
# Generasi 265
# Best Distance = 80344.35559499598
# Total Fitness = 0.0008028824219740605
#
# Generasi 266
# Best Distance = 80344.35559499598
# Total Fitness = 0.000794627161394007
#
# Generasi 267
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007792904533237778
#
# Generasi 268
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007724948085647145
#
# Generasi 269
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007738415692841844
#
# Generasi 270
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007608484687417624
#
# Generasi 271
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007950930940949783
#
# Generasi 272
# Best Distance = 80344.35559499598
# Total Fitness = 0.0007867626972773446
#
# Generasi 273
# Best Distance = 80344.35559499598
# Total Fitness = 0.0008130514879467215
#
# Generasi 274
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008229135528755782
#
# Generasi 275
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008261447097742596
#
# Generasi 276
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008476046742162553
#
# Generasi 277
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008423199911513823
#
# Generasi 278
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008316220091306711
#
# Generasi 279
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008383388863319071
#
# Generasi 280
# Best Distance = 78226.55499452564
# Total Fitness = 0.0008253159160623612
#
# Generasi 281
# Best Distance = 77985.58635922636
# Total Fitness = 0.000805942772794001
#
# Generasi 282
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008119051316294504
#
# Generasi 283
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008457161088455911
#
# Generasi 284
# Best Distance = 77985.58635922636
# Total Fitness = 0.0007973542824277991
#
# Generasi 285
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008363441895186674
#
# Generasi 286
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008776217117219109
#
# Generasi 287
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008808600816121267
#
# Generasi 288
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008669890710365699
#
# Generasi 289
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008938390204394717
#
# Generasi 290
# Best Distance = 77985.58635922636
# Total Fitness = 0.0008784878482568157
#
# Generasi 291
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009329733967470041
#
# Generasi 292
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009613604741596972
#
# Generasi 293
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009464971509540211
#
# Generasi 294
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009377346199193988
#
# Generasi 295
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009275703393507483
#
# Generasi 296
# Best Distance = 74433.64822694345
# Total Fitness = 0.000904665603500769
#
# Generasi 297
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008873622901066347
#
# Generasi 298
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008853797884530989
#
# Generasi 299
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008769612411839022
#
# Generasi 300
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008769071774140547
#
# Generasi 301
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008632232385001959
#
# Generasi 302
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008770081920082811
#
# Generasi 303
# Best Distance = 74433.64822694345
# Total Fitness = 0.000894413249108387
#
# Generasi 304
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009066482033178532
#
# Generasi 305
# Best Distance = 74433.64822694345
# Total Fitness = 0.0009108250586159033
#
# Generasi 306
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008983069314605131
#
# Generasi 307
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008985874739935126
#
# Generasi 308
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008840215572071489
#
# Generasi 309
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008668928760634278
#
# Generasi 310
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008518838282912156
#
# Generasi 311
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008444770455827083
#
# Generasi 312
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008525005063317272
#
# Generasi 313
# Best Distance = 74433.64822694345
# Total Fitness = 0.000868173270390668
#
# Generasi 314
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008543287911306947
#
# Generasi 315
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008488225821958236
#
# Generasi 316
# Best Distance = 74433.64822694345
# Total Fitness = 0.00080646613817773
#
# Generasi 317
# Best Distance = 74433.64822694345
# Total Fitness = 0.0008254604667396382
#
# Generasi 318
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008241295112626197
#
# Generasi 319
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008282926485483476
#
# Generasi 320
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008414081128010193
#
# Generasi 321
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008568990251502856
#
# Generasi 322
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008718297077502823
#
# Generasi 323
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008567395172766145
#
# Generasi 324
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008591301856680641
#
# Generasi 325
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008717756546975047
#
# Generasi 326
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008526568746337796
#
# Generasi 327
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008423889763596512
#
# Generasi 328
# Best Distance = 71961.01216789655
# Total Fitness = 0.000848482807831589
#
# Generasi 329
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008502496415957341
#
# Generasi 330
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008494320423917658
#
# Generasi 331
# Best Distance = 71961.01216789655
# Total Fitness = 0.0008331657188725446
#
# Generasi 332
# Best Distance = 69218.03865328203
# Total Fitness = 0.000840730447036841
#
# Generasi 333
# Best Distance = 69218.03865328203
# Total Fitness = 0.000886675554028409
#
# Generasi 334
# Best Distance = 69218.03865328203
# Total Fitness = 0.0009055177425408571
#
# Generasi 335
# Best Distance = 69218.03865328203
# Total Fitness = 0.0008696630353075931
#
# Generasi 336
# Best Distance = 69218.03865328203
# Total Fitness = 0.0008636056287834919
#
# Generasi 337
# Best Distance = 69218.03865328203
# Total Fitness = 0.0008546476399808009
#
# Generasi 338
# Best Distance = 69218.03865328203
# Total Fitness = 0.0008485386136742983
# Generasi 339
# Best Distance = 69218.03865328203
# Total Fitness = 0.0008719480438579328
#
# Generasi 340
# Best Distance = 69218.03865328203
# Total Fitness = 0.0009285816266952364
#
# Generasi 341
# Best Distance = 69218.03865328203
# Total Fitness = 0.0009572773397241818
#
# Generasi 342
# Best Distance = 68055.14221541124
# Total Fitness = 0.0009764764442417752
#
# Generasi 343
# Best Distance = 68055.14221541124
# Total Fitness = 0.000997495395512556
#
# Generasi 344
# Best Distance = 66487.31645883578
# Total Fitness = 0.0010201909217614571
#
# Generasi 345
# Best Distance = 65786.32020218951
# Total Fitness = 0.0010173575733535647
#
# Generasi 346
# Best Distance = 65786.32020218951
# Total Fitness = 0.0010143088996058141
#
# Generasi 347
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009695978878277176
#
# Generasi 348
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009627125146150048
#
# Generasi 349
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009568301695504676
#
# Generasi 350
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009491371482400237
#
# Generasi 351
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009618100362763268
#
# Generasi 352
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009874405134970964
#
# Generasi 353
# Best Distance = 65786.32020218951
# Total Fitness = 0.0009637956918151938
#
# Generasi 354
# Best Distance = 65786.32020218951
# Total Fitness = 0.00097598395399915
#
# Generasi 355
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009550476994086704
#
# Generasi 356
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009566867279337733
#
# Generasi 357
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009777089558005174
#
# Generasi 358
# Best Distance = 65632.8418076549
# Total Fitness = 0.0010056666880884576
#
# Generasi 359
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009881778872044423
#
# Generasi 360
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009990458967523512
#
# Generasi 361
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009893025880226285
#
# Generasi 362
# Best Distance = 65632.8418076549
# Total Fitness = 0.001011704695639165
#
# Generasi 363
# Best Distance = 65632.8418076549
# Total Fitness = 0.0009844511403224697
#
# Generasi 364
# Best Distance = 65632.8418076549
# Total Fitness = 0.0010222106804357277
#
# Generasi 365
# Best Distance = 65632.8418076549
# Total Fitness = 0.0010200982948224287
#
# Generasi 366
# Best Distance = 64276.922886774955
# Total Fitness = 0.0010181704211881038
#
# Generasi 367
# Best Distance = 64276.922886774955
# Total Fitness = 0.001042342286031265
#
# Generasi 368
# Best Distance = 64276.922886774955
# Total Fitness = 0.001084631181936531
#
# Generasi 369
# Best Distance = 64276.922886774955
# Total Fitness = 0.0010410558947232121
#
# Generasi 370
# Best Distance = 64276.922886774955
# Total Fitness = 0.0010066626933432077
#
# Generasi 371
# Best Distance = 64276.922886774955
# Total Fitness = 0.0009614042467168328
#
# Generasi 372
# Best Distance = 64276.922886774955
# Total Fitness = 0.0009619307311219075
#
# Generasi 373
# Best Distance = 64041.667739430806
# Total Fitness = 0.0009532821444003819
#
# Generasi 374
# Best Distance = 64041.667739430806
# Total Fitness = 0.0009629154580732868
#
# Generasi 375
# Best Distance = 64041.667739430806
# Total Fitness = 0.000958103483944379
#
# Generasi 376
# Best Distance = 64041.667739430806
# Total Fitness = 0.0009416348133373614
#
# Generasi 377
# Best Distance = 64041.667739430806
# Total Fitness = 0.0009150691536675949
#
# Generasi 378
# Best Distance = 63399.94871527864
# Total Fitness = 0.0009288718927667592
#
# Generasi 379
# Best Distance = 63399.94871527864
# Total Fitness = 0.0009365581667377604
#
# Generasi 380
# Best Distance = 63399.94871527864
# Total Fitness = 0.0009377042727407327
#
# Generasi 381
# Best Distance = 62739.30444662838
# Total Fitness = 0.0009891710659492728
#
# Generasi 382
# Best Distance = 62739.30444662838
# Total Fitness = 0.0010027664840938
#
# Generasi 383
# Best Distance = 62667.089175372945
# Total Fitness = 0.0010011847199017825
#
# Generasi 384
# Best Distance = 62667.089175372945
# Total Fitness = 0.0009724515708752715
#
# Generasi 385
# Best Distance = 62667.089175372945
# Total Fitness = 0.0009309033061478107
#
# Generasi 386
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009482335748007319
#
# Generasi 387
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009551742896563914
#
# Generasi 388
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009812090751204934
#
# Generasi 389
# Best Distance = 61326.347174413546
# Total Fitness = 0.0010130206704021712
#
# Generasi 390
# Best Distance = 61326.347174413546
# Total Fitness = 0.0010206175769371766
#
# Generasi 391
# Best Distance = 61326.347174413546
# Total Fitness = 0.000995590781162781
#
# Generasi 392
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009874726121345337
#
# Generasi 393
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009857639035123018
#
# Generasi 394
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009675968720557664
#
# Generasi 395
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009872165911030094
#
# Generasi 396
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009633425711642817
#
# Generasi 397
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009610961312580734
#
# Generasi 398
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009556194102858853
#
# Generasi 399
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009133871112436294
#
# Generasi 400
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009206317196490189
#
# Generasi 401
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009055839410916987
#
# Generasi 402
# Best Distance = 61326.347174413546
# Total Fitness = 0.0009638751468133102
#
# Generasi 403
# Best Distance = 61326.347174413546
# Total Fitness = 0.000979474392903466
#
# Generasi 404
# Best Distance = 59664.75426751061
# Total Fitness = 0.0010108736908568039
#
# Generasi 405
# Best Distance = 59664.75426751061
# Total Fitness = 0.0010205466543395081
#
# Generasi 406
# Best Distance = 59664.75426751061
# Total Fitness = 0.0010573203218771933
#
# Generasi 407
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011280762528722422
#
# Generasi 408
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011765413825747233
#
# Generasi 409
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011525426238963587
#
# Generasi 410
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011630775565172424
#
# Generasi 411
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011122186741127245
#
# Generasi 412
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011029832820507119
#
# Generasi 413
# Best Distance = 59468.26816294893
# Total Fitness = 0.0011270885733883017
#
# Generasi 414
# Best Distance = 59432.91119632653
# Total Fitness = 0.0011040148330813528
#
# Generasi 415
# Best Distance = 59432.91119632653
# Total Fitness = 0.0010883529184650305
#
# Generasi 416
# Best Distance = 59432.91119632653
# Total Fitness = 0.001067088637548459
#
# Generasi 417
# Best Distance = 59432.91119632653
# Total Fitness = 0.0010520086164365026
#
# Generasi 418
# Best Distance = 59432.91119632653
# Total Fitness = 0.001025558371537425
#
# Generasi 419
# Best Distance = 59432.91119632653
# Total Fitness = 0.000985935216358806
#
# Generasi 420
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009597863891236629
#
# Generasi 421
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009536088493878593
#
# Generasi 422
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009571468038268712
#
# Generasi 423
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009476527603227023
#
# Generasi 424
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009574787868835831
#
# Generasi 425
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009737020761923347
#
# Generasi 426
# Best Distance = 59432.91119632653
# Total Fitness = 0.0009606185476314539
#
# Generasi 427
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009839890922876998
#
# Generasi 428
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009750735479280225
#
# Generasi 429
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009767652490139857
#
# Generasi 430
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009515499311031145
#
# Generasi 431
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009547025484626555
#
# Generasi 432
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009511152517009651
#
# Generasi 433
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009531377280253445
#
# Generasi 434
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009588773691405989
#
# Generasi 435
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009409171397784266
#
# Generasi 436
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009524816437902266
#
# Generasi 437
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009409839219021057
#
# Generasi 438
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009563303588239166
#
# Generasi 439
# Best Distance = 59009.681561625046
# Total Fitness = 0.000979792900993997
#
# Generasi 440
# Best Distance = 59009.681561625046
# Total Fitness = 0.0009997853623191666
#
# Generasi 441
# Best Distance = 59009.681561625046
# Total Fitness = 0.0010051465494447524
#
# Generasi 442
# Best Distance = 59009.681561625046
# Total Fitness = 0.0010320158634333399
#
# Generasi 443
# Best Distance = 59009.681561625046
# Total Fitness = 0.001024315243018918
#
# Generasi 444
# Best Distance = 59009.681561625046
# Total Fitness = 0.0010329142772710475
#
# Generasi 445
# Best Distance = 59009.681561625046
# Total Fitness = 0.0010196487945742518
#
# Generasi 446
# Best Distance = 59009.681561625046
# Total Fitness = 0.0010004920371705956
#
# Generasi 447
# Best Distance = 58796.929443428635
# Total Fitness = 0.0010221597389727325
#
# Generasi 448
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010331313857985783
#
# Generasi 449
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010521893741954084
#
# Generasi 450
# Best Distance = 58644.73805600138
# Total Fitness = 0.001009910084234541
#
# Generasi 451
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009710432221663175
#
# Generasi 452
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009894571993805889
#
# Generasi 453
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009624901922162994
#
# Generasi 454
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009556045944245519
#
# Generasi 455
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010131649974293722
# Generasi 456
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009882941441284067
#
# Generasi 457
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010058465583204664
#
# Generasi 458
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009809287505674355
#
# Generasi 459
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009891359454309743
#
# Generasi 460
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009686813944277414
#
# Generasi 461
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010097987455188794
#
# Generasi 462
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009915249096366617
#
# Generasi 463
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010091070625518484
#
# Generasi 464
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009931318977188016
#
# Generasi 465
# Best Distance = 58644.73805600138
# Total Fitness = 0.001001203897873805
#
# Generasi 466
# Best Distance = 58644.73805600138
# Total Fitness = 0.001024261239562321
#
# Generasi 467
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010099978917199176
#
# Generasi 468
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010616604142289088
#
# Generasi 469
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010673427986650822
#
# Generasi 470
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010377980936571312
#
# Generasi 471
# Best Distance = 58644.73805600138
# Total Fitness = 0.001043763135634445
#
# Generasi 472
# Best Distance = 58644.73805600138
# Total Fitness = 0.001030841743018124
#
# Generasi 473
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010351097705484878
#
# Generasi 474
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010582648846401623
#
# Generasi 475
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010160066033319854
#
# Generasi 476
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009708448000264857
#
# Generasi 477
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009627346226945012
#
# Generasi 478
# Best Distance = 58644.73805600138
# Total Fitness = 0.000948853467832882
#
# Generasi 479
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009567534766539487
#
# Generasi 480
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009605950756744385
#
# Generasi 481
# Best Distance = 58644.73805600138
# Total Fitness = 0.001004540421379979
#
# Generasi 482
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009925330119981751
#
# Generasi 483
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010076628735530319
#
# Generasi 484
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010146285239819716
#
# Generasi 485
# Best Distance = 58644.73805600138
# Total Fitness = 0.001010964479069422
#
# Generasi 486
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010291442009764513
#
# Generasi 487
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010067439701899748
#
# Generasi 488
# Best Distance = 58644.73805600138
# Total Fitness = 0.0009969539092672054
#
# Generasi 489
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010053030989435423
#
# Generasi 490
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010134630305411393
#
# Generasi 491
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010032684341692605
#
# Generasi 492
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010261200924081065
#
# Generasi 493
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010364325655393052
#
# Generasi 494
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010706976737566932
#
# Generasi 495
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010583353861993129
#
# Generasi 496
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010428707148207573
#
# Generasi 497
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010604930952255805
#
# Generasi 498
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010289879075236047
#
# Generasi 499
# Best Distance = 58644.73805600138
# Total Fitness = 0.0010179583204898463
#
# Generasi 500
# Best Distance = 58644.73805600138
# Total Fitness = 0.001025100315150749
#
#
# Best Path:[33, 12, 41, 2, 4, 26, 32, 39, 14, 13, 34, 25, 29, 16, 1, 40, 15, 44, 31, 8, 38, 9, 36, 48, 5, 42, 10, 45, 35, 24, 21, 20, 47, 11, 3, 22, 23, 46, 7, 18, 28, 6, 37, 30, 19, 27, 17, 43]
# Best Distance: 58644.73805600138
